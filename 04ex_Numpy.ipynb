# %% [markdown]
# ### Numpy basics

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1\. Find the row, column and overall means for the following matrix:
#
# ```python
# m = np.arange(12).reshape((3,4))
# ```

# %%
m = np.arange(12).reshape((3,4))
#print(m)

print("Media delle colonne:", np.mean(m, 0))
print("Media delle righe:", np.mean(m, 1))
print("Media di ogni cella:", np.mean(m))
# Out:
# Media delle colonne: [4. 5. 6. 7.]
# Media delle righe: [1.5 5.5 9.5]
# Media di ogni cella: 5.5

# %% [markdown]
# 2\. Find the outer product of the following two vecotrs
#
# ```python
# u = np.array([1,3,5,7])
# v = np.array([2,4,6,8])
# ```
#
# Do this in the following ways:
#
#    * Using the function outer in numpy
#    * Using a nested for loop or list comprehension
#    * Using numpy broadcasting operatoins

# %%
u = np.array([1,3,5,7])
v = np.array([2,4,6,8])

print("np.outer:\n", np.outer(u, v))
print("comprehension:\n", np.array([[ui * vi for vi in v] for ui in u]).reshape(4, 4))
print("broadcasting:\n", np.reshape(u, (4, 1)) * v)
# Out:
# np.outer:
#  [[ 2  4  6  8]
#  [ 6 12 18 24]
#  [10 20 30 40]
#  [14 28 42 56]]
# comprehension:
#  [[ 2  4  6  8]
#  [ 6 12 18 24]
#  [10 20 30 40]
#  [14 28 42 56]]
# broadcasting:
#  [[ 2  4  6  8]
#  [ 6 12 18 24]
#  [10 20 30 40]
#  [14 28 42 56]]

# %% [markdown]
# 3\. Create a 10 by 6 matrix of random uniform numbers. Set all rows with any entry less than 0.1 to be zero
#
# Hint: Use the following numpy functions - np.random.random, np.any as well as Boolean indexing and the axis argument.

# %%
m = np.random.random(size=(10, 6))
m[m < 0.1] = 0
print(m)
# Out:
# [[0.41531392 0.19137381 0.35825492 0.50003752 0.91921345 0.62638524]
#  [0.67014409 0.95046426 0.23392255 0.57091555 0.38635386 0.47822607]
#  [0.32731257 0.1175303  0.90440376 0.66897937 0.01331595 0.14168194]
#  [0.2905162  0.86985376 0.84103417 0.80168601 0.36246207 0.40019681]
#  [0.60375051 0.12480665 0.97474455 0.97098585 0.4218191  0.78269664]
#  [0.60824133 0.51683042 0.43518896 0.4119359  0.15370169 0.91066664]
#  [0.17011438 0.11289622 0.83781768 0.63288541 0.31597227 0.49874235]
#  [0.09196818 0.13468222 0.36898425 0.34774295 0.59460966 0.23889716]
#  [0.26363205 0.65268589 0.74746469 0.615915   0.11832028 0.7151418 ]
#  [0.84671228 0.89165199 0.95765623 0.23643998 0.16236028 0.86946027]]
# [[0.41531392 0.19137381 0.35825492 0.50003752 0.91921345 0.62638524]
#  [0.67014409 0.95046426 0.23392255 0.57091555 0.38635386 0.47822607]
#  [0.32731257 0.1175303  0.90440376 0.66897937 0.         0.14168194]
#  [0.2905162  0.86985376 0.84103417 0.80168601 0.36246207 0.40019681]
# ...

# %% [markdown]
# 4\. Use np.linspace to create an array of 100 numbers between 0 and 2π (includsive).
#
#   * Extract every 10th element using slice notation
#   * Reverse the array using slice notation
#   * Extract elements where the absolute difference between the sine and cosine functions evaluated at that element is less than 0.1
#   * Make a plot showing the sin and cos functions and indicate where they are close

# %%
ar = np.linspace(0, 2*np.pi, 100)
ar_10 = ar[::10]
ar_rev = ar[::-1]
indexes = np.abs(np.sin(ar) - np.cos(ar)) < 0.1
ar_sc = ar[indexes]


plt.scatter(ar, np.sin(ar))
plt.scatter(ar[indexes], np.sin(ar)[indexes], c="green")
plt.scatter(ar, np.cos(ar))
plt.scatter(ar[indexes], np.cos(ar)[indexes], c="green")

# %% [markdown]
# 5\. Create a matrix that shows the 10 by 10 multiplication table.
#
#  * Find the trace of the matrix
#  * Extract the anto-diagonal (this should be ```array([10, 18, 24, 28, 30, 30, 28, 24, 18, 10])```)
#  * Extract the diagnoal offset by 1 upwards (this should be ```array([ 2,  6, 12, 20, 30, 42, 56, 72, 90])```)

# %%
u = np.arange(1, 11)
v = np.arange(1, 11)
m = np.reshape(u, (10, 1)) * v

print("trace:", np.trace(m))
print("antidiagonal", np.flipud(m).diagonal())
print("diagonal+1", m.diagonal(1))
# Out:
# trace: 385
# antidiagonal [10 18 24 28 30 30 28 24 18 10]
# diagonal+1 [ 2  6 12 20 30 42 56 72 90]

# %% [markdown]
# 6\. Use broadcasting to create a grid of distances
#
# Route 66 crosses the following cities in the US: Chicago, Springfield, Saint-Louis, Tulsa, Oklahoma City, Amarillo, Santa Fe, Albuquerque, Flagstaff, Los Angeles
# The corresponding positions in miles are: 0, 198, 303, 736, 871, 1175, 1475, 1544, 1913, 2448
#
#   * Construct a 2D grid of distances among each city along Route 66
#   * Convert that in km (those savages...)

# %%
cumul_miles = np.array([0, 198, 303, 736, 871, 1175, 1475, 1544, 1913, 2448])

m = np.abs(cumul_miles.reshape(len(cumul_miles), 1) - cumul_miles)
m_km = np.round(m * 1.60934)
print(m_km)
# Out:
# [[   0.  319.  488. 1184. 1402. 1891. 2374. 2485. 3079. 3940.]
#  [ 319.    0.  169.  866. 1083. 1572. 2055. 2166. 2760. 3621.]
#  [ 488.  169.    0.  697.  914. 1403. 1886. 1997. 2591. 3452.]
#  [1184.  866.  697.    0.  217.  707. 1189. 1300. 1894. 2755.]
#  [1402. 1083.  914.  217.    0.  489.  972. 1083. 1677. 2538.]
#  [1891. 1572. 1403.  707.  489.    0.  483.  594. 1188. 2049.]
#  [2374. 2055. 1886. 1189.  972.  483.    0.  111.  705. 1566.]
#  [2485. 2166. 1997. 1300. 1083.  594.  111.    0.  594. 1455.]
#  [3079. 2760. 2591. 1894. 1677. 1188.  705.  594.    0.  861.]
#  [3940. 3621. 3452. 2755. 2538. 2049. 1566. 1455.  861.    0.]]

# %% [markdown]
# 7\. Prime numbers sieve: compute the prime numbers in the 0-N (N=99 to start with) range with a sieve (mask).
#   * Constract a shape (100,) boolean array, the mask
#   * Identify the multiples of each number starting from 2 and set accordingly the corresponding mask element
#   * Apply the mask to obtain an array of ordered prime numbers
#   * Check the performances (timeit); how does it scale with N?
#   * Implement the optimization suggested in the [sieve of Eratosthenes](https://en.wikipedia.org/wiki/Sieve_of_Eratosthenes)

# %%
import timeit

def prime_naive(max_n):
    max_n = max_n + 1
    mask = np.ones(shape=(max_n), dtype=bool)
    numbers = np.arange(0, max_n)

    mask[0:2] = False
    for k in range(2, max_n):
        for i in range(2, (k // 2) + 1):
            if k % i == 0:
                mask[k] = False
                break
    
    return numbers[mask]

def prime_eratosthene(max_n):
    max_n = max_n + 1
    mask = np.ones(shape=(max_n), dtype=bool)
    numbers = np.arange(0, max_n)

    mask[0:2] = False
    p = 2
    for i in range(2, max_n):
        if not mask[i]:
            continue

        p = numbers[i]
        for k in range(2 * p, max_n, p):
            mask[k] = False
    return numbers[mask]

N = 9999
#print("Array uguali?", np.all(np.equal(prime_naive(N), prime_eratosthene(N))))
#print(prime_naive(N))
#print(prime_eratosthene(N))


rep = 10
print(timeit.timeit(f'prime_naive({N})', globals=globals(), number=rep))
print(timeit.timeit(f'prime_eratosthene({N})', globals=globals(), number=rep))
# Out:
# 3.8743269000005967
# 0.06304480000108015

# %% [markdown]
# **N.B. the following exercises are meant to be solved only if you are familiar with the numpy random library. If not you can skip them (postponed for one of the next exercise sessions)**

# %% [markdown]
# 8\. Diffusion using random walk
#
# Consider a simple random walk process: at each step in time, a walker jumps right or left (+1 or -1) with equal probability. The goal is to find the typical distance from the origin of a random walker after a given amount of time.
# To do that, let's simulate many walkers and create a 2D array with each walker as a raw and the actual time evolution as columns
#
#   * Take 1000 walkers and let them walk for 200 steps
#   * Use randint to create a 2D array of size walkers x steps with values -1 or 1
#   * Build the actual walking distances for each walker (i.e. another 2D array "summing on each raw")
#   * Take the square of that 2D array (elementwise)
#   * Compute the mean of the squared distances at each step (i.e. the mean along the columns)
#   * Plot the average distances (sqrt(distance\*\*2)) as a function of time (step)
#
# Did you get what you expected?

# %%
n_walkers = 1000
steps = 200


m = np.zeros(shape=n_walkers)
foo = np.round(np.random.random(size=(n_walkers, steps)))
foo[foo == 0] = -1

walk_distances = np.cumsum(foo, 1)
walk_distances = np.square(walk_distances)

walk_mean = np.mean(walk_distances, axis=1)
plt.plot(np.sqrt(walk_mean))
# Out:
# (1000,)

# %% [markdown]
# 9\. Analyze a data file
#   * Download the population of hares, lynxes and carrots at the beginning of the last century.
#     ```python
#     ! wget https://www.dropbox.com/s/3vigxoqayo389uc/populations.txt
#     ```
#
#   * Check the content by looking within the file
#   * Load the data (use an appropriate numpy method) into a 2D array
#   * Create arrays out of the columns, the arrays being (in order): *year*, *hares*, *lynxes*, *carrots*
#   * Plot the 3 populations over the years
#   * Compute the main statistical properties of the dataset (mean, std, correlations, etc.)
#   * Which species has the highest population each year?
#
# Do you feel there is some evident correlation here? [Studies](https://www.enr.gov.nt.ca/en/services/lynx/lynx-snowshoe-hare-cycle) tend to believe so.

# %%
# import os
# os.environ.update(comspec="powershell.exe")

# ! wget https://www.dropbox.com/s/3vigxoqayo389uc/populations.txt

data = np.loadtxt("./populations.txt")
# print(data)

years = data[:, 0]
hares = data[:, 1]
lynxes = data[:, 2]
carrots = data[:, 3]

plt.plot(years, hares, label="conigli")
plt.plot(years, lynxes, label="linci")
plt.plot(years, carrots, label="carrots")
plt.legend()

print("medie (conigli, linci, carote): ", np.mean(data[:, 1]), np.mean(data[:, 2]), np.mean(data[:, 3]))
print("dev std (conigli, linci, carote): ", np.std(data[:, 1]), np.std(data[:, 2]), np.std(data[:, 3]))
# todo: correlations

max_each_year = np.argmax(data[:, 1:], axis=1)
animals = np.array(["Conigli", "Linci", "Carote"])
maximus = np.concatenate((years, animals[max_each_year])).reshape(2, len(years)).T
print(maximus)


# np.concatenate((years.reshape(len(years), 1), maxis.reshape(len(maxis), 1)), axis=1)
# Out:
# medie (conigli, linci, carote):  34080.95238095238 20166.666666666668 42400.0
# dev std (conigli, linci, carote):  20897.906458089667 16254.591536908763 3322.5062255844787
# [['1900.0' 'Carote']
#  ['1901.0' 'Carote']
#  ['1902.0' 'Conigli']
#  ['1903.0' 'Conigli']
#  ['1904.0' 'Linci']
#  ['1905.0' 'Linci']
#  ['1906.0' 'Carote']
#  ['1907.0' 'Carote']
#  ['1908.0' 'Carote']
#  ['1909.0' 'Carote']
#  ['1910.0' 'Carote']
#  ['1911.0' 'Carote']
#  ['1912.0' 'Conigli']
#  ['1913.0' 'Conigli']
#  ['1914.0' 'Conigli']
#  ['1915.0' 'Linci']
#  ['1916.0' 'Carote']
#  ['1917.0' 'Carote']
#  ['1918.0' 'Carote']
#  ['1919.0' 'Carote']
#  ['1920.0' 'Carote']]
